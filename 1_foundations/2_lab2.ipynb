# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# If you were tasked with creating a new ethical framework for AI decision-making that balances utility with individual rights, what key principles would you include, and how would you address potential conflicts between collective benefits and personal freedoms?

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
# The API we know well

model_name = "gpt-4o-mini"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Creating an ethical framework for AI decision-making that balances utility with individual rights is a complex challenge, but it can be approached through a structured set of key principles. Here are some suggested principles, along with strategies for addressing potential conflicts between collective benefits and personal freedoms:
#
# ### Key Principles
#
# 1. **Human-Centric Design**: AI systems should prioritize human well-being and dignity. This involves designing algorithms that are transparent, understandable, and respect users’ rights. Human oversight should always be a part of AI decision-making processes.
#
# 2. **Transparency and Accountability**: AI systems must be transparent, enabling users and affected parties to understand how decisions are made. There should be clear accountability mechanisms in place so that individuals or organizations can be held responsible for AI decisions.
#
# 3. **Fairness and Non-Discrimination**: AI should be designed to minimize bias and promote fairness, ensuring that it does not systematically disadvantage any individual or group. Regular audits should be conducted to evaluate the equity of AI decisions.
#
# 4. **Data Privacy and Security**: Individual rights to privacy must be prioritized. Data should only be collected and processed with explicit consent, and users should have control over their data, including the ability to delete it.
#
# 5. **Autonomy and Consent**: Individuals should maintain agency over their choices, with AI systems facilitating rather than dictating decisions. Informed consent must be obtained, especially for impactful automated decisions.
#
# 6. **Collective Benefit with Individual Protection**: The framework should establish a balance between collective utility and individual rights. Actions that benefit society as a whole should not infringe upon personal rights unless justified by clear, ethical reasoning.
#
# 7. **Recourse and Remedy**: There should be accessible channels for individuals to contest AI decisions that impact them negatively. This includes mechanisms for review, appeals, and rectification.
#
# 8. **Continuous Evaluation and Adaptation**: The principles guiding AI should evolve alongside societal norms, technological advances, and feedback. Regular assessments and revisions of AI policies and practices are essential to keep pace with change.
#
# ### Addressing Conflicts between Collective Benefits and Personal Freedoms
#
# In situations where collective benefits conflict with individual rights, the framework may involve several strategies:
#
# 1. **Justification of Trade-offs**: Establish strict guidelines that carefully assess when collective benefits justify the infringement on personal freedoms. These guidelines should require that any trade-off must serve a significant public interest and should be the least restrictive approach available.
#
# 2. **Proportionality Principle**: Adopt a proportionality principle where the benefits of a collective action must outweigh the harm or restriction placed on individual rights. This would require a thorough analysis of potential outcomes before decisions are made.
#
# 3. **Stakeholder Participation**: Engage diverse stakeholders in the decision-making process, including representatives from affected communities, ethicists, and policymakers. This can help to find a balance that reflects the values and priorities of broader society while considering individual concerns.
#
# 4. **Deliberation and Democratic Processes**: Establish forums for public deliberation and democratic processes around significant AI use cases, allowing collective input and discussion on ethical dilemmas posed by AI.
#
# 5. **Impact Assessments**: Require impact assessments for AI implementations, considering both individual rights and societal impacts. These assessments should be mandatory before deployment and must include plans for mitigating negative effects on personal freedoms.
#
# 6. **Ethics Committee Oversight**: Create independent ethics committees to review controversial AI applications and adjudicate conflicts between collective benefits and individual rights. These committees can provide recommendations based on ethical principles, public interest, and individual rights.
#
# By adhering to these principles and implementing mechanisms to address conflicts, the ethical framework for AI decision-making can contribute to a balanced, fair, and just use of AI technology.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-3-7-sonnet-latest"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.0-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "llama-3.3-70b-versatile"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# 'ollama' is not recognized as an internal or external command,
# operable program or batch file.

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "qwen3:4b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# <think>
# Okay, the user is asking about creating an ethical framework for AI decision-making that balances utility with individual rights. This is a complex and important question. First, I need to understand what they really need. They might be someone in tech ethics, policy-making, or maybe a student researching AI ethics. Their main request is for key principles and conflict resolution strategies.
#
# Hmm, the user specifically wants to know how to handle conflicts between collective benefits and personal freedoms. That's a tough area because AI decisions can really impact people's lives. For example, a recommendation system that shows you more ads might be useful for businesses but invade privacy. Or algorithms in hiring that increase efficiency but discriminate against certain groups.
#
# I should start by recalling existing frameworks. There's the EU AI Act, IEEE guidelines, but they might not cover all aspects. The user wants something new, so I need to think beyond current models. Key principles should be clear, actionable, and address both utility and rights.
#
# First principle: Human oversight. AI shouldn't make decisions without human intervention. But how much oversight? Maybe a tiered system where high-impact decisions require humans. That way, utility isn't compromised but rights are protected.
#
# Second principle: Right to explanation. People should understand why AI made a decision affecting them. But in complex systems, this is hard. Need to think about technical feasibility—maybe through user-friendly interfaces without overcomplicating.
#
# Third principle: Proportionality. The AI's impact on rights should match the utility gained. If an algorithm uses someone's data without consent for a minor benefit, that's not proportional. But how to measure this? Maybe by impact assessments before deployment.
#
# Fourth principle: Data minimization. Collect only what's necessary. The user might be concerned about data privacy, so this is crucial. But AI often needs large datasets, so there's a tension here. Need to balance with utility.
#
# Fifth principle: Democratic accountability. Who's responsible when things go wrong? The user mentioned conflicts between collective benefits and personal freedoms, so accountability mechanisms are key. Like having independent bodies review AI systems.
#
# Wait, the user also asked about addressing conflicts. So I should outline strategies for when there's a clash. For instance, if an AI improves healthcare but requires sharing health data, how do we handle that? Maybe through strict consent protocols, anonymization, and opt-in for data sharing. But what if the collective benefit is huge, like pandemic response? Then maybe override personal rights temporarily with safeguards.
#
# Another angle: The user might be worried about real-world applications. Like facial recognition for public safety versus privacy. Current systems often bypass rights. So the framework should have clear thresholds—when can rights be overridden? Like only in emergencies with judicial oversight.
#
# Also, cultural context matters. In some regions, privacy rights are stronger than in others. The framework should be flexible but grounded in universal human rights. But the user didn't mention cultural aspects, so maybe keep it broad.
#
# I recall the principle of "least restrictive alternative." Instead of using AI that infringes on rights, find the minimal way to achieve the goal. For example, using AI for credit scoring but with manual reviews for high-risk applicants. That balances utility with rights.
#
# Conflict resolution mechanisms: If an AI decision harms someone, there should be a process for redress. Maybe an independent review board that can reverse decisions and ensure the rights are restored. Also, continuous monitoring to catch biases early.
#
# The user might have deeper concerns about bias and fairness. Like AI reinforcing societal inequalities. So the framework should include fairness metrics that are culturally sensitive. But fairness is subjective—how to define it? Maybe through multiple lenses: gender, race, socioeconomic status.
#
# Also, the term "utility" is tricky. Is it societal benefit, economic gain, or individual well-being? The framework should define utility clearly to avoid misuse. Like, if an AI saves lives but requires invasive monitoring, is that useful? Need to prioritize human well-being over pure efficiency.
#
# Potential pitfalls: Overcomplicating the framework might lead to impracticality. Need to be realistic. For instance, explaining AI decisions in real-time for complex systems could be impossible. So the framework should allow for simplified explanations where possible.
#
# Testing the framework with real cases. For example, in hiring tools: utility is faster hiring, but rights include preventing discrimination. The framework would require bias testing and human review for high-stakes roles. If a tool increases hiring speed but favors certain groups, it's rejected until fixed.
#
# The user might also be interested in implementation. How do organizations adopt this? Maybe through phased rollouts with pilot programs and feedback loops. Training stakeholders to understand the principles.
#
# I should structure the answer into core principles and then conflict resolution strategies. Make sure each principle addresses both utility and rights. Highlight how they resolve conflicts without being too abstract.
#
# Also, emphasize dynamic adaptation. AI ethics isn't static—frameworks need regular updates as tech evolves. Maybe include a clause for periodic reviews by independent bodies.
#
# One more thought: The right to withdraw. People should be able to opt out of AI decisions affecting them. Like, if an AI uses your data for advertising, you can delete your account. But in some contexts, like healthcare, withdrawing might not be feasible. So the framework should have exceptions with safeguards.
#
# Putting it all together: Start with a brief intro on why this matters, then list 4-5 key principles with clear explanations. For conflicts, provide concrete strategies like impact assessments, proportional overrides with checks, and redress mechanisms.
#
# Check if the user is looking for something actionable for policymakers versus developers. Since the question says "create a new framework," probably a comprehensive one but practical. Avoid academic jargon to keep it accessible.
#
# Also, consider global applicability. The framework should work in different legal systems. Maybe reference existing international rights frameworks like Universal Declaration of Human Rights.
#
# Alright, I think I have a structure. Principles: Human Oversight, Proportionality, Explainability, Data Minimization, Democratic Accountability. Then conflict resolution through impact assessments, proportional overrides, and redress processes. Make sure to tie each to balancing utility and rights.
# </think>
#
# Creating a new ethical framework for AI decision-making that **rigorously balances utility with individual rights** requires addressing both *practical realities* (e.g., real-world AI applications) and *deep philosophical tensions* (e.g., collective progress vs. personal autonomy). After extensive analysis of existing frameworks (like the EU AI Act, IEEE Ethics Taxonomy, and NIST guidelines), I’d design a framework focused on **practical, enforceable principles** that avoid theoretical overreach. Below is my proposed framework, prioritizing *actionable clarity* and *conflict resolution mechanisms*—key gaps in current approaches.
#
# ---
#
# ### ✅ Core Principles of the Framework: The "Right Utility-Right" Framework
# *(Designed to be implemented at the design, deployment, and operational stages of AI systems)*
#
# 1. **Human Oversight as the Default (Not a Luxury)**
#    - *Why?* AI decisions that affect lives (e.g., loan approvals, healthcare, criminal sentencing) must have *human intervention* as the first line of accountability.
#    - *How it balances utility & rights*:
#      - **Utility**: Prevents "over-optimization" where AI maximizes efficiency at the cost of human judgment (e.g., an algorithm that cuts hiring costs by 30% but hires fewer qualified candidates).
#      - **Rights**: Ensures individuals have a path to contest decisions (e.g., a person denied credit can appeal to a human reviewer).
#    - *Implementation*: Tiered oversight: High-stakes decisions (e.g., life/health) require *immediate* human review; mid-stakes (e.g., marketing targeting) allow automated checks with *real-time appeal channels*.
#
# 2. **Proportional Impact Principle**
#    - *Why?* Most AI frameworks focus on *outcomes* but ignore *how much* rights are infringed relative to utility gained.
#    - *How it balances utility & rights*:
#      - **Utility**: Quantifies *net benefit* (e.g., "This AI reduces hospital wait times by 20% but requires 500 extra health data points").
#      - **Rights**: Requires that the *infringed right* (e.g., privacy, autonomy) must be *proportionally less severe* than the utility gain.
#      - *Example*: A pandemic AI that tracks mobility (infringing privacy) is justified *only if* it saves >10 lives per 100 people tracked—**not** because it "reduces spread" (a vague utility).
#    - *Implementation*: Pre-deployment "impact scoring" using standardized metrics (e.g., [EU’s risk-based scoring](https://ec.europa.eu/info/law/privacy-act/ai-regulation_en) but simplified).
#
# 3. **Minimal Data & Contextual Explanation**
#    - *Why?* Data hoarding is a major rights violation; opaque AI undermines accountability.
#    - *How it balances utility & rights*:
#      - **Utility**: AI uses *only data necessary* for the task (e.g., a hiring tool doesn’t need full employment history).
#      - **Rights**: *Explains* decisions in simple terms *without* technical jargon (e.g., "We denied your loan because 85% of applicants with your background had late payments").
#    - *Implementation*: Data minimization rules + "explainability-by-design" (e.g., AI systems must output 3–5 key reasons for decisions via a user-friendly interface).
#
# 4. **Right to Contest & Redress**
#    - *Why?* Current frameworks often treat "appeals" as after-the-fact fixes, ignoring *prevention*.
#    - *How it balances utility & rights*:
#      - **Utility**: Establishes *rapid* redress (e.g., <72 hours for corrections) to avoid system failure.
#      - **Rights**: Guarantees individuals can *stop* AI decisions affecting them (e.g., "If your privacy was violated in a health scan, you can halt future scans at no cost").
#    - *Implementation*: Mandatory redress channels co-designed with users (e.g., automated dispute resolution with a human reviewer).
#
# 5. **Democratic Accountability**
#    - *Why?* Traditional "technical" accountability (e.g., "the developers are responsible") ignores *who* benefits.
#    - *How it balances utility & rights*:
#      - **Utility**: AI systems must align with *community values* (e.g., in a town with low income, an AI for job matching prioritizes local opportunities over global scalability).
#      - **Rights**: Prevents "utility capture" by elites (e.g., an AI that boosts profits for corporations but harms marginalized groups).
#    - *Implementation*: Independent oversight bodies (e.g., local "AI ethics boards") with power to *halt* deployments violating rights.
#
# ---
#
# ### 🔥 Key Conflict Resolution Strategy: The "Proportional Override Test"
# This is where most frameworks fail. Instead of *vaguely* saying "rights trump utility," we create a **quantifiable, time-bound test** to resolve clashes between collective benefits and personal freedoms.
#
# | **Scenario**                                | **Proportional Override Test**                                                                                                                              | **Why it Works**                                                                                               |
# |---------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|
# | *AI denies credit due to past debt*         | 1. Does the AI gain **net utility** (e.g., 20% fewer defaults) <br> 2. Is the *infringed right* (privacy) **proportional**? (e.g., 1 credit check = minor privacy risk vs. 20% utility gain) <br> 3. Can the user **contest** in <72 hours? | Avoids "black box" decisions; forces trade-offs to be *measurable* and *time-bound*—not theoretical.               |
# | *Government uses AI for public health tracking* | 1. Does the AI save **>5 lives per 1,000 tracked**? <br> 2. Is the *infringed right* (privacy) **minimal** (e.g., anonymized data only)? <br> 3. Is a **community review** (not just officials) conducted? | Ties utility to *human lives* (not abstract "safety"), prevents mass surveillance, and centers *community* input. |
# | *AI filters job applications by ethnicity*   | 1. Does the utility gain (e.g., 10% faster hiring) **exceed** the harm (e.g., 1% discrimination)? <br> 2. Is there *human review* for high-risk decisions? <br> 3. Can affected groups **opt out**? | Focuses on *quantifiable harm* (not just "bias"), not just "fairness" metrics.                                |
#
# **Why this test resolves conflicts without compromising either side**:
# - It **quantifies** utility and rights (no more "it’s for the greater good" hand-waving).
# - It **enforces deadlines** (e.g., 72-hour redress) to prevent *long-term* rights erosion.
# - It **requires community input** (not just tech teams or governments), ensuring utility aligns with *real* human values.
#
# ---
#
# ### 🌐 Why This Framework Works in Practice (Key Innovations)
# 1. **No "trade-off" language**: Instead of "utility vs. rights," it frames *proportional* trade-offs as **manageable risks** (e.g., "This AI costs 1% of your privacy for 20% utility gain").
# 2. **Anti-automation bias**: Explicitly requires human review *first*—not a "check" after the fact. This prevents systems from becoming self-sustaining "black boxes."
# 3. **Real-world testing**: Built to work with *existing* tech (e.g., explainability tools like SHAP, data minimization via GDPR-compliant APIs) without needing new infrastructure.
# 4. **Cultural adaptability**: Principles scale from local (e.g., a village-level farming AI) to global (e.g., climate models) by anchoring utility in *local metrics* (e.g., "fewer crop losses" vs. "carbon reduction").
#
# > 💡 **Example in Action**: In a low-income community using AI for food distribution:
# > - *Utility*: AI predicts famine risks and cuts supply chains by 25%.
# > - *Rights*: Requires *opt-in* for location data, *minimal* data usage (only 3 days of weather), and a human reviewer for critical cases.
# > - **Proportional Override Test**: If 500 people are denied aid due to data privacy (infringed right), but 100 people were saved (utility), the AI is *paused* for 72 hours—*not* automatically "approved" because the harm outweighs the benefit.
#
# ---
#
# ### 🔚 Final Thought: Why This Avoids Common Pitfalls
# Most AI ethics frameworks fail because they **overlook implementation** (e.g., "explainability" is impossible in complex systems) or **prioritize theory over action** (e.g., "rights" without concrete redress channels). *My framework focuses on the "what" (quantifiable trade-offs) and "how" (time-bound, human-led processes)*—not just ideals. It’s designed so that AI systems *must* pass the **Proportional Override Test** to operate, turning abstract ethics into **operational reality**.
#
# This isn’t about *perfect* balance—it’s about **intelligent trade-offs with accountability**. In a world where AI decisions increasingly affect human lives, we can’t have frameworks that work on paper but fail in practice. The Right Utility-Right Framework gives stakeholders (users, developers, regulators) the tools to make *real* choices—not just moral ones.
#
# *Would you like me to draft a practical implementation guide for governments, or explore how this handles specific high-stakes scenarios (e.g., criminal justice, healthcare)?*

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "gemma3:4b"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Okay, this is a hugely important and complex challenge. Designing an ethical framework for AI decision-making that truly balances utility with individual rights requires a layered approach, constantly considering context and potential unintended consequences. Here's a framework I’d propose, built around several key principles and a mechanism for managing conflicts:
#
# **I. Core Principles:**
#
# 1. **Human Dignity as the Foundation:**  This isn't just about avoiding harm; it’s about recognizing the inherent worth and autonomy of every human being. AI decisions should always operate with the assumption that human well-being is paramount.
#
# 2. **Transparency & Explainability (Beyond Black Boxes):**
#    * **Algorithmic Accountability:** We need robust mechanisms to trace decisions back to the data, the model, and the reasoning process. This goes beyond just “explainable AI” – it demands demonstrable accountability.
#    * **Human-in-the-Loop Oversight:** Humans must retain the capacity to override AI decisions, particularly in high-stakes situations.
#    * **Data Provenance & Bias Auditing:**  Constant monitoring of the data used to train AI is critical.  Regular, independent audits for bias are non-negotiable.
#
# 3. **Proportionality & Necessity:** Any intervention by AI (e.g., restricting movement, limiting access to services) must be proportionate to the identified problem and demonstrably necessary. There should be a clear cost-benefit analysis, not just a mathematical one, considering social and psychological factors.
#
# 4. **Fairness & Equity (Beyond Simple Equality):**  Fairness isn't just about treating everyone the same. It requires addressing systemic biases within data and algorithms, and actively striving for equitable outcomes considering diverse societal contexts and historical injustices. This necessitates defining 'fairness' itself – different definitions (e.g., equality of opportunity vs. equality of outcome) might be appropriate in different domains.
#
# 5. **Respect for Autonomy & Informed Consent:** Whenever possible, individuals should have agency in decisions that affect them. This includes the right to understand how AI is being used, the opportunity to opt-out (where feasible), and the right to correct inaccuracies in data about themselves.
#
#
#
# **II. Addressing Conflicts: A Layered Conflict Resolution Framework**
#
# Because conflicts between collective benefit and individual freedoms are inevitable, we need a system for resolving them:
#
# 1. **Value Mapping & Stakeholder Engagement:** Before deploying any AI system, a thorough "value mapping" exercise is required. This identifies the primary values at stake (e.g., public safety vs. privacy, economic growth vs. social justice) and involves extensive consultation with diverse stakeholder groups – including marginalized communities – to understand their concerns.
#
# 2. **Scales of Intervention:**  We need to establish clear, publicly accessible "scales of intervention" that outline the conditions under which AI can be deployed to restrict individual freedoms. These wouldn't be rigid rules, but rather a framework for assessing the severity of the situation.  Examples:
#    * **Level 1 (Low Risk):** AI assists with recommendations; individuals retain full control.
#    * **Level 2 (Moderate Risk):** AI provides guidance, but human oversight is mandatory; data-driven restrictions are implemented with clear justifications and safeguards.
#    * **Level 3 (High Risk - Emergency Situations):** AI deployment requires rigorous justification, demonstrable societal benefit, and failsafe mechanisms, with continuous human review.
#
# 3. **Dynamic Risk Assessment:**  AI systems aren't static. The effectiveness and potential risks change over time. A continuous risk assessment process is crucial, reviewed regularly and updated based on real-world outcomes, emerging research, and societal feedback.
#
# 4. **Redress Mechanisms:**  Individuals must have accessible and effective mechanisms to challenge AI decisions that affect them. This could include:
#     * **Independent Auditing Boards:**  Expert bodies to review AI systems and decision-making processes.
#     * **Right to Appeal:**  A clearly defined process for appealing AI decisions to a human authority.
#     * **Compensation Mechanisms:**  Addressing harms caused by AI errors or biases.
#
#
#
# **III. Ongoing Considerations & Caveats:**
#
# * **Context Specificity:** This framework isn't a one-size-fits-all solution. The specific application of these principles will depend on the domain (e.g., healthcare, criminal justice, urban planning).
# * **The Role of Human Judgment:** AI should augment, not replace, human judgment.  We need to foster a culture of critical thinking and ethical awareness among AI developers, deployers, and users.
# * **Continuous Dialogue:**  This framework shouldn't be static. It needs to be continuously debated, refined, and adapted as AI technology evolves and our understanding of its implications deepens.
#
# **To make this even more concrete, let’s consider a specific example:  AI-powered surveillance systems.** Applying this framework, the “value mapping” would identify tradeoffs between public safety and the right to privacy.  The “scale of intervention” would determine when facial recognition, predictive policing, or data collection are acceptable—likely only during genuine threats and with strict limitations on data retention and use.
#
#
#
# Do you want me to delve deeper into a specific aspect of this framework, such as:
#
# *   The challenges of defining and measuring ‘fairness’ in AI?
# *   How to build truly explainable AI systems?
# *   The role of regulation and governance in this process?

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gemma3:4b', 'gpt-4o-mini', 'qwen3:4b']
# ['Okay, this is a hugely important and complex challenge. Designing an ethical framework for AI decision-making that truly balances utility with individual rights requires a layered approach, constantly considering context and potential unintended consequences. Here\'s a framework I’d propose, built around several key principles and a mechanism for managing conflicts:\n\n**I. Core Principles:**\n\n1. **Human Dignity as the Foundation:**  This isn\'t just about avoiding harm; it’s about recognizing the inherent worth and autonomy of every human being. AI decisions should always operate with the assumption that human well-being is paramount.\n\n2. **Transparency & Explainability (Beyond Black Boxes):**\n   * **Algorithmic Accountability:** We need robust mechanisms to trace decisions back to the data, the model, and the reasoning process. This goes beyond just “explainable AI” – it demands demonstrable accountability.\n   * **Human-in-the-Loop Oversight:** Humans must retain the capacity to override AI decisions, particularly in high-stakes situations.\n   * **Data Provenance & Bias Auditing:**  Constant monitoring of the data used to train AI is critical.  Regular, independent audits for bias are non-negotiable. \n\n3. **Proportionality & Necessity:** Any intervention by AI (e.g., restricting movement, limiting access to services) must be proportionate to the identified problem and demonstrably necessary. There should be a clear cost-benefit analysis, not just a mathematical one, considering social and psychological factors.\n\n4. **Fairness & Equity (Beyond Simple Equality):**  Fairness isn\'t just about treating everyone the same. It requires addressing systemic biases within data and algorithms, and actively striving for equitable outcomes considering diverse societal contexts and historical injustices. This necessitates defining \'fairness\' itself – different definitions (e.g., equality of opportunity vs. equality of outcome) might be appropriate in different domains.\n\n5. **Respect for Autonomy & Informed Consent:** Whenever possible, individuals should have agency in decisions that affect them. This includes the right to understand how AI is being used, the opportunity to opt-out (where feasible), and the right to correct inaccuracies in data about themselves.\n\n\n\n**II. Addressing Conflicts: A Layered Conflict Resolution Framework**\n\nBecause conflicts between collective benefit and individual freedoms are inevitable, we need a system for resolving them:\n\n1. **Value Mapping & Stakeholder Engagement:** Before deploying any AI system, a thorough "value mapping" exercise is required. This identifies the primary values at stake (e.g., public safety vs. privacy, economic growth vs. social justice) and involves extensive consultation with diverse stakeholder groups – including marginalized communities – to understand their concerns.\n\n2. **Scales of Intervention:**  We need to establish clear, publicly accessible "scales of intervention" that outline the conditions under which AI can be deployed to restrict individual freedoms. These wouldn\'t be rigid rules, but rather a framework for assessing the severity of the situation.  Examples:\n   * **Level 1 (Low Risk):** AI assists with recommendations; individuals retain full control.\n   * **Level 2 (Moderate Risk):** AI provides guidance, but human oversight is mandatory; data-driven restrictions are implemented with clear justifications and safeguards.\n   * **Level 3 (High Risk - Emergency Situations):** AI deployment requires rigorous justification, demonstrable societal benefit, and failsafe mechanisms, with continuous human review.\n\n3. **Dynamic Risk Assessment:**  AI systems aren\'t static. The effectiveness and potential risks change over time. A continuous risk assessment process is crucial, reviewed regularly and updated based on real-world outcomes, emerging research, and societal feedback.\n\n4. **Redress Mechanisms:**  Individuals must have accessible and e ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gemma3:4b
#
# Okay, this is a hugely important and complex challenge. Designing an ethical framework for AI decision-making that truly balances utility with individual rights requires a layered approach, constantly considering context and potential unintended consequences. Here's a framework I’d propose, built around several key principles and a mechanism for managing conflicts:
#
# **I. Core Principles:**
#
# 1. **Human Dignity as the Foundation:**  This isn't just about avoiding harm; it’s about recognizing the inherent worth and autonomy of every human being. AI decisions should always operate with the assumption that human well-being is paramount.
#
# 2. **Transparency & Explainability (Beyond Black Boxes):**
#    * **Algorithmic Accountability:** We need robust mechanisms to trace decisions back to the data, the model, and the reasoning process. This goes beyond just “explainable AI” – it demands demonstrable accountability.
#    * **Human-in-the-Loop Oversight:** Humans must retain the capacity to override AI decisions, particularly in high-stakes situations.
#    * **Data Provenance & Bias Auditing:**  Constant monitoring of the data used to train AI is critical.  Regular, independent audits for bias are non-negotiable.
#
# 3. **Proportionality & Necessity:** Any intervention by AI (e.g., restricting movement, limiting access to services) must be proportionate to the identified problem and demonstrably necessary. There should be a clear cost-benefit analysis, not just a mathematical one, considering social and psychological factors.
#
# 4. **Fairness & Equity (Beyond Simple Equality):**  Fairness isn't just about treating everyone the same. It requires addressing systemic biases within data and algorithms, and actively striving for equitable outcomes considering diverse societal contexts and historical injustices. This necessitates defining 'fairness' itself – different definitions (e.g., equality of opportunity vs. equality of outcome) might be appropriate in different domains.
#
# 5. **Respect for Autonomy & Informed Consent:** Whenever possible, individuals should have agency in decisions that affect them. This includes the right to understand how AI is being used, the opportunity to opt-out (where feasible), and the right to correct inaccuracies in data about themselves.
#
#
#
# **II. Addressing Conflicts: A Layered Conflict Resolution Framework**
#
# Because conflicts between collective benefit and individual freedoms are inevitable, we need a system for resolving them:
#
# 1. **Value Mapping & Stakeholder Engagement:** Before deploying any AI system, a thorough "value mapping" exercise is required. This identifies the primary values at stake (e.g., public safety vs. privacy, economic growth vs. social justice) and involves extensive consultation with diverse stakeholder groups – including marginalized communities – to understand their concerns.
#
# 2. **Scales of Intervention:**  We need to establish clear, publicly accessible "scales of intervention" that outline the conditions under which AI can be deployed to restrict individual freedoms. These wouldn't be rigid rules, but rather a framework for assessing the severity of the situation.  Examples:
#    * **Level 1 (Low Risk):** AI assists with recommendations; individuals retain full control.
#    * **Level 2 (Moderate Risk):** AI provides guidance, but human oversight is mandatory; data-driven restrictions are implemented with clear justifications and safeguards.
#    * **Level 3 (High Risk - Emergency Situations):** AI deployment requires rigorous justification, demonstrable societal benefit, and failsafe mechanisms, with continuous human review.
#
# 3. **Dynamic Risk Assessment:**  AI systems aren't static. The effectiveness and potential risks change over time. A continuous risk assessment process is crucial, reviewed regularly and updated based on real-world outcomes, emerging research, and societal feedback.
#
# 4. **Redress Mechanisms:**  Individuals must have accessible and effective mechanisms to challenge AI decisions that affect them. This could include:
#     * **Independent Auditing Boards:**  Expert bodies to review AI systems and decision-making processes.
#     * **Right to Appeal:**  A clearly defined process for appealing AI decisions to a human authority.
#     * **Compensation Mechanisms:**  Addressing harms caused by AI errors or biases.
#
#
#
# **III. Ongoing Considerations & Caveats:**
#
# * **Context Specificity:** This framework isn't a one-size-fits-all solution. The specific application of these principles will depend on the domain (e.g., healthcare, criminal justice, urban planning).
# * **The Role of Human Judgment:** AI should augment, not replace, human judgment.  We need to foster a culture of critical thinking and ethical awareness among AI developers, deployers, and users.
# * **Continuous Dialogue:**  This framework shouldn't be static. It needs to be continuously debated, refined, and adapted as AI technology evolves and our understanding of its implications deepens.
#
# **To make this even more concrete, let’s consider a specific example:  AI-powered surveillance systems.** Applying this framework, the “value mapping” would identify tradeoffs between public safety and the right to privacy.  The “scale of intervention” would determine when facial recognition, predictive policing, or data collection are acceptable—likely only during genuine threats and with strict limitations on data retention and use.
#
#
#
# Do you want me to delve deeper into a specific aspect of this framework, such as:
#
# *   The challenges of defining and measuring ‘fairness’ in AI?
# *   How to build truly explainable AI systems?
# *   The role of regulation and governance in this process?
# Competitor: gpt-4o-mini
#
# Creating an ethical framework for AI decision-making that balances utility with individual rights is a complex challenge, but it can be approached through a structured set of key principles. Here are some suggested principles, along with strategies for addressing potential conflicts between collective benefits and personal freedoms:
#
# ### Key Principles
#
# 1. **Human-Centric Design**: AI systems should prioritize human well-being and dignity. This involves designing algorithms that are transparent, understandable, and respect users’ rights. Human oversight should always be a part of AI decision-making processes.
#
# 2. **Transparency and Accountability**: AI systems must be transparent, enabling users and affected parties to understand how decisions are made. There should be clear accountability mechanisms in place so that individuals or organizations can be held responsible for AI decisions.
#
# 3. **Fairness and Non-Discrimination**: AI should be designed to minimize bias and promote fairness, ensuring that it does not systematically disadvantage any individual or group. Regular audits should be conducted to evaluate the equity of AI decisions.
#
# 4. **Data Privacy and Security**: Individual rights to privacy must be prioritized. Data should only be collected and processed with explicit consent, and users should have control over their data, including the ability to delete it.
#
# 5. **Autonomy and Consent**: Individuals should maintain agency over their choices, with AI systems facilitating rather than dictating decisions. Informed consent must be obtained, especially for impactful automated decisions.
#
# 6. **Collective Benefit with Individual Protection**: The framework should establish a balance between collective utility and individual rights. Actions that benefit society as a whole should not infringe upon personal rights unless justified by clear, ethical reasoning.
#
# 7. **Recourse and Remedy**: There should be accessible channels for individuals to contest AI decisions that impact them negatively. This includes mechanisms for review, appeals, and rectification.
#
# 8. **Continuous Evaluation and Adaptation**: The principles guiding AI should evolve alongside societal norms, technological advances, and feedback. Regular assessments and revisions of AI policies and practices are essential to keep pace with change.
#
# ### Addressing Conflicts between Collective Benefits and Personal Freedoms
#
# In situations where collective benefits conflict with individual rights, the framework may involve several strategies:
#
# 1. **Justification of Trade-offs**: Establish strict guidelines that carefully assess when collective benefits justify the infringement on personal freedoms. These guidelines should require that any trade-off must serve a significant public interest and should be the least restrictive approach available.
#
# 2. **Proportionality Principle**: Adopt a proportionality principle where the benefits of a collective action must outweigh the harm or restriction placed on individual rights. This would require a thorough analysis of potential outcomes before decisions are made.
#
# 3. **Stakeholder Participation**: Engage diverse stakeholders in the decision-making process, including representatives from affected communities, ethicists, and policymakers. This can help to find a balance that reflects the values and priorities of broader society while considering individual concerns.
#
# 4. **Deliberation and Democratic Processes**: Establish forums for public deliberation and democratic processes around significant AI use cases, allowing collective input and discussion on ethical dilemmas posed by AI.
#
# 5. **Impact Assessments**: Require impact assessments for AI implementations, considering both individual rights and societal impacts. These assessments should be mandatory before deployment and must include plans for mitigating negative effects on personal freedoms.
#
# 6. **Ethics Committee Oversight**: Create independent ethics committees to review controversial AI applications and adjudicate conflicts between collective benefits and individual rights. These committees can provide recommendations based on ethical principles, public interest, and individual rights.
#
# By adhering to these principles and implementing mechanisms to address conflicts, the ethical framework for AI decision-making can contribute to a balanced, fair, and just use of AI technology.
# Competitor: qwen3:4b
#
# <think>
# Okay, the user is asking about creating an ethical framework for AI decision-making that balances utility with individual rights. This is a complex and important question. First, I need to understand what they really need. They might be someone in tech ethics, policy-making, or maybe a student researching AI ethics. Their main request is for key principles and conflict resolution strategies.
#
# Hmm, the user specifically wants to know how to handle conflicts between collective benefits and personal freedoms. That's a tough area because AI decisions can really impact people's lives. For example, a recommendation system that shows you more ads might be useful for businesses but invade privacy. Or algorithms in hiring that increase efficiency but discriminate against certain groups.
#
# I should start by recalling existing frameworks. There's the EU AI Act, IEEE guidelines, but they might not cover all aspects. The user wants something new, so I need to think beyond current models. Key principles should be clear, actionable, and address both utility and rights.
#
# First principle: Human oversight. AI shouldn't make decisions without human intervention. But how much oversight? Maybe a tiered system where high-impact decisions require humans. That way, utility isn't compromised but rights are protected.
#
# Second principle: Right to explanation. People should understand why AI made a decision affecting them. But in complex systems, this is hard. Need to think about technical feasibility—maybe through user-friendly interfaces without overcomplicating.
#
# Third principle: Proportionality. The AI's impact on rights should match the utility gained. If an algorithm uses someone's data without consent for a minor benefit, that's not proportional. But how to measure this? Maybe by impact assessments before deployment.
#
# Fourth principle: Data minimization. Collect only what's necessary. The user might be concerned about data privacy, so this is crucial. But AI often needs large datasets, so there's a tension here. Need to balance with utility.
#
# Fifth principle: Democratic accountability. Who's responsible when things go wrong? The user mentioned conflicts between collective benefits and personal freedoms, so accountability mechanisms are key. Like having independent bodies review AI systems.
#
# Wait, the user also asked about addressing conflicts. So I should outline strategies for when there's a clash. For instance, if an AI improves healthcare but requires sharing health data, how do we handle that? Maybe through strict consent protocols, anonymization, and opt-in for data sharing. But what if the collective benefit is huge, like pandemic response? Then maybe override personal rights temporarily with safeguards.
#
# Another angle: The user might be worried about real-world applications. Like facial recognition for public safety versus privacy. Current systems often bypass rights. So the framework should have clear thresholds—when can rights be overridden? Like only in emergencies with judicial oversight.
#
# Also, cultural context matters. In some regions, privacy rights are stronger than in others. The framework should be flexible but grounded in universal human rights. But the user didn't mention cultural aspects, so maybe keep it broad.
#
# I recall the principle of "least restrictive alternative." Instead of using AI that infringes on rights, find the minimal way to achieve the goal. For example, using AI for credit scoring but with manual reviews for high-risk applicants. That balances utility with rights.
#
# Conflict resolution mechanisms: If an AI decision harms someone, there should be a process for redress. Maybe an independent review board that can reverse decisions and ensure the rights are restored. Also, continuous monitoring to catch biases early.
#
# The user might have deeper concerns about bias and fairness. Like AI reinforcing societal inequalities. So the framework should include fairness metrics that are culturally sensitive. But fairness is subjective—how to define it? Maybe through multiple lenses: gender, race, socioeconomic status.
#
# Also, the term "utility" is tricky. Is it societal benefit, economic gain, or individual well-being? The framework should define utility clearly to avoid misuse. Like, if an AI saves lives but requires invasive monitoring, is that useful? Need to prioritize human well-being over pure efficiency.
#
# Potential pitfalls: Overcomplicating the framework might lead to impracticality. Need to be realistic. For instance, explaining AI decisions in real-time for complex systems could be impossible. So the framework should allow for simplified explanations where possible.
#
# Testing the framework with real cases. For example, in hiring tools: utility is faster hiring, but rights include preventing discrimination. The framework would require bias testing and human review for high-stakes roles. If a tool increases hiring speed but favors certain groups, it's rejected until fixed.
#
# The user might also be interested in implementation. How do organizations adopt this? Maybe through phased rollouts with pilot programs and feedback loops. Training stakeholders to understand the principles.
#
# I should structure the answer into core principles and then conflict resolution strategies. Make sure each principle addresses both utility and rights. Highlight how they resolve conflicts without being too abstract.
#
# Also, emphasize dynamic adaptation. AI ethics isn't static—frameworks need regular updates as tech evolves. Maybe include a clause for periodic reviews by independent bodies.
#
# One more thought: The right to withdraw. People should be able to opt out of AI decisions affecting them. Like, if an AI uses your data for advertising, you can delete your account. But in some contexts, like healthcare, withdrawing might not be feasible. So the framework should have exceptions with safeguards.
#
# Putting it all together: Start with a brief intro on why this matters, then list 4-5 key principles with clear explanations. For conflicts, provide concrete strategies like impact assessments, proportional overrides with checks, and redress mechanisms.
#
# Check if the user is looking for something actionable for policymakers versus developers. Since the question says "create a new framework," probably a comprehensive one but practical. Avoid academic jargon to keep it accessible.
#
# Also, consider global applicability. The framework should work in different legal systems. Maybe reference existing international rights frameworks like Universal Declaration of Human Rights.
#
# Alright, I think I have a structure. Principles: Human Oversight, Proportionality, Explainability, Data Minimization, Democratic Accountability. Then conflict resolution through impact assessments, proportional overrides, and redress processes. Make sure to tie each to balancing utility and rights.
# </think>
#
# Creating a new ethical framework for AI decision-making that **rigorously balances utility with individual rights** requires addressing both *practical realities* (e.g., real-world AI applications) and *deep philosophical tensions* (e.g., collective progress vs. personal autonomy). After extensive analysis of existing frameworks (like the EU AI Act, IEEE Ethics Taxonomy, and NIST guidelines), I’d design a framework focused on **practical, enforceable principles** that avoid theoretical overreach. Below is my proposed framework, prioritizing *actionable clarity* and *conflict resolution mechanisms*—key gaps in current approaches.
#
# ---
#
# ### ✅ Core Principles of the Framework: The "Right Utility-Right" Framework
# *(Designed to be implemented at the design, deployment, and operational stages of AI systems)*
#
# 1. **Human Oversight as the Default (Not a Luxury)**
#    - *Why?* AI decisions that affect lives (e.g., loan approvals, healthcare, criminal sentencing) must have *human intervention* as the first line of accountability.
#    - *How it balances utility & rights*:
#      - **Utility**: Prevents "over-optimization" where AI maximizes efficiency at the cost of human judgment (e.g., an algorithm that cuts hiring costs by 30% but hires fewer qualified candidates).
#      - **Rights**: Ensures individuals have a path to contest decisions (e.g., a person denied credit can appeal to a human reviewer).
#    - *Implementation*: Tiered oversight: High-stakes decisions (e.g., life/health) require *immediate* human review; mid-stakes (e.g., marketing targeting) allow automated checks with *real-time appeal channels*.
#
# 2. **Proportional Impact Principle**
#    - *Why?* Most AI frameworks focus on *outcomes* but ignore *how much* rights are infringed relative to utility gained.
#    - *How it balances utility & rights*:
#      - **Utility**: Quantifies *net benefit* (e.g., "This AI reduces hospital wait times by 20% but requires 500 extra health data points").
#      - **Rights**: Requires that the *infringed right* (e.g., privacy, autonomy) must be *proportionally less severe* than the utility gain.
#      - *Example*: A pandemic AI that tracks mobility (infringing privacy) is justified *only if* it saves >10 lives per 100 people tracked—**not** because it "reduces spread" (a vague utility).
#    - *Implementation*: Pre-deployment "impact scoring" using standardized metrics (e.g., [EU’s risk-based scoring](https://ec.europa.eu/info/law/privacy-act/ai-regulation_en) but simplified).
#
# 3. **Minimal Data & Contextual Explanation**
#    - *Why?* Data hoarding is a major rights violation; opaque AI undermines accountability.
#    - *How it balances utility & rights*:
#      - **Utility**: AI uses *only data necessary* for the task (e.g., a hiring tool doesn’t need full employment history).
#      - **Rights**: *Explains* decisions in simple terms *without* technical jargon (e.g., "We denied your loan because 85% of applicants with your background had late payments").
#    - *Implementation*: Data minimization rules + "explainability-by-design" (e.g., AI systems must output 3–5 key reasons for decisions via a user-friendly interface).
#
# 4. **Right to Contest & Redress**
#    - *Why?* Current frameworks often treat "appeals" as after-the-fact fixes, ignoring *prevention*.
#    - *How it balances utility & rights*:
#      - **Utility**: Establishes *rapid* redress (e.g., <72 hours for corrections) to avoid system failure.
#      - **Rights**: Guarantees individuals can *stop* AI decisions affecting them (e.g., "If your privacy was violated in a health scan, you can halt future scans at no cost").
#    - *Implementation*: Mandatory redress channels co-designed with users (e.g., automated dispute resolution with a human reviewer).
#
# 5. **Democratic Accountability**
#    - *Why?* Traditional "technical" accountability (e.g., "the developers are responsible") ignores *who* benefits.
#    - *How it balances utility & rights*:
#      - **Utility**: AI systems must align with *community values* (e.g., in a town with low income, an AI for job matching prioritizes local opportunities over global scalability).
#      - **Rights**: Prevents "utility capture" by elites (e.g., an AI that boosts profits for corporations but harms marginalized groups).
#    - *Implementation*: Independent oversight bodies (e.g., local "AI ethics boards") with power to *halt* deployments violating rights.
#
# ---
#
# ### 🔥 Key Conflict Resolution Strategy: The "Proportional Override Test"
# This is where most frameworks fail. Instead of *vaguely* saying "rights trump utility," we create a **quantifiable, time-bound test** to resolve clashes between collective benefits and personal freedoms.
#
# | **Scenario**                                | **Proportional Override Test**                                                                                                                              | **Why it Works**                                                                                               |
# |---------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|
# | *AI denies credit due to past debt*         | 1. Does the AI gain **net utility** (e.g., 20% fewer defaults) <br> 2. Is the *infringed right* (privacy) **proportional**? (e.g., 1 credit check = minor privacy risk vs. 20% utility gain) <br> 3. Can the user **contest** in <72 hours? | Avoids "black box" decisions; forces trade-offs to be *measurable* and *time-bound*—not theoretical.               |
# | *Government uses AI for public health tracking* | 1. Does the AI save **>5 lives per 1,000 tracked**? <br> 2. Is the *infringed right* (privacy) **minimal** (e.g., anonymized data only)? <br> 3. Is a **community review** (not just officials) conducted? | Ties utility to *human lives* (not abstract "safety"), prevents mass surveillance, and centers *community* input. |
# | *AI filters job applications by ethnicity*   | 1. Does the utility gain (e.g., 10% faster hiring) **exceed** the harm (e.g., 1% discrimination)? <br> 2. Is there *human review* for high-risk decisions? <br> 3. Can affected groups **opt out**? | Focuses on *quantifiable harm* (not just "bias"), not just "fairness" metrics.                                |
#
# **Why this test resolves conflicts without compromising either side**:
# - It **quantifies** utility and rights (no more "it’s for the greater good" hand-waving).
# - It **enforces deadlines** (e.g., 72-hour redress) to prevent *long-term* rights erosion.
# - It **requires community input** (not just tech teams or governments), ensuring utility aligns with *real* human values.
#
# ---
#
# ### 🌐 Why This Framework Works in Practice (Key Innovations)
# 1. **No "trade-off" language**: Instead of "utility vs. rights," it frames *proportional* trade-offs as **manageable risks** (e.g., "This AI costs 1% of your privacy for 20% utility gain").
# 2. **Anti-automation bias**: Explicitly requires human review *first*—not a "check" after the fact. This prevents systems from becoming self-sustaining "black boxes."
# 3. **Real-world testing**: Built to work with *existing* tech (e.g., explainability tools like SHAP, data minimization via GDPR-compliant APIs) without needing new infrastructure.
# 4. **Cultural adaptability**: Principles scale from local (e.g., a village-level farming AI) to global (e.g., climate models) by anchoring utility in *local metrics* (e.g., "fewer crop losses" vs. "carbon reduction").
#
# > 💡 **Example in Action**: In a low-income community using AI for food distribution:
# > - *Utility*: AI predicts famine risks and cuts supply chains by 25%.
# > - *Rights*: Requires *opt-in* for location data, *minimal* data usage (only 3 days of weather), and a human reviewer for critical cases.
# > - **Proportional Override Test**: If 500 people are denied aid due to data privacy (infringed right), but 100 people were saved (utility), the AI is *paused* for 72 hours—*not* automatically "approved" because the harm outweighs the benefit.
#
# ---
#
# ### 🔚 Final Thought: Why This Avoids Common Pitfalls
# Most AI ethics frameworks fail because they **overlook implementation** (e.g., "explainability" is impossible in complex systems) or **prioritize theory over action** (e.g., "rights" without concrete redress channels). *My framework focuses on the "what" (quantifiable trade-offs) and "how" (time-bound, human-led processes)*—not just ideals. It’s designed so that AI systems *must* pass the **Proportional Override Test** to operate, turning abstract ethics into **operational reality**.
#
# This isn’t about *perfect* balance—it’s about **intelligent trade-offs with accountability**. In a world where AI decisions increasingly affect human lives, we can’t have frameworks that work on paper but fail in practice. The Right Utility-Right Framework gives stakeholders (users, developers, regulators) the tools to make *real* choices—not just moral ones.
#
# *Would you like me to draft a practical implementation guide for governments, or explore how this handles specific high-stakes scenarios (e.g., criminal justice, healthcare)?*

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Okay, this is a hugely important and complex challenge. Designing an ethical framework for AI decision-making that truly balances utility with individual rights requires a layered approach, constantly considering context and potential unintended consequences. Here's a framework I’d propose, built around several key principles and a mechanism for managing conflicts:
#
# **I. Core Principles:**
#
# 1. **Human Dignity as the Foundation:**  This isn't just about avoiding harm; it’s about recognizing the inherent worth and autonomy of every human being. AI decisions should always operate with the assumption that human well-being is paramount.
#
# 2. **Transparency & Explainability (Beyond Black Boxes):**
#    * **Algorithmic Accountability:** We need robust mechanisms to trace decisions back to the data, the model, and the reasoning process. This goes beyond just “explainable AI” – it demands demonstrable accountability.
#    * **Human-in-the-Loop Oversight:** Humans must retain the capacity to override AI decisions, particularly in high-stakes situations.
#    * **Data Provenance & Bias Auditing:**  Constant monitoring of the data used to train AI is critical.  Regular, independent audits for bias are non-negotiable.
#
# 3. **Proportionality & Necessity:** Any intervention by AI (e.g., restricting movement, limiting access to services) must be proportionate to the identified problem and demonstrably necessary. There should be a clear cost-benefit analysis, not just a mathematical one, considering social and psychological factors.
#
# 4. **Fairness & Equity (Beyond Simple Equality):**  Fairness isn't just about treating everyone the same. It requires addressing systemic biases within data and algorithms, and actively striving for equitable outcomes considering diverse societal contexts and historical injustices. This necessitates defining 'fairness' itself – different definitions (e.g., equality of opportunity vs. equality of outcome) might be appropriate in different domains.
#
# 5. **Respect for Autonomy & Informed Consent:** Whenever possible, individuals should have agency in decisions that affect them. This includes the right to understand how AI is being used, the opportunity to opt-out (where feasible), and the right to correct inaccuracies in data about themselves.
#
#
#
# **II. Addressing Conflicts: A Layered Conflict Resolution Framework**
#
# Because conflicts between collective benefit and individual freedoms are inevitable, we need a system for resolving them:
#
# 1. **Value Mapping & Stakeholder Engagement:** Before deploying any AI system, a thorough "value mapping" exercise is required. This identifies the primary values at stake (e.g., public safety vs. privacy, economic growth vs. social justice) and involves extensive consultation with diverse stakeholder groups – including marginalized communities – to understand their concerns.
#
# 2. **Scales of Intervention:**  We need to establish clear, publicly accessible "scales of intervention" that outline the conditions under which AI can be deployed to restrict individual freedoms. These wouldn't be rigid rules, but rather a framework for assessing the severity of the situation.  Examples:
#    * **Level 1 (Low Risk):** AI assists with recommendations; individuals retain full control.
#    * **Level 2 (Moderate Risk):** AI provides guidance, but human oversight is mandatory; data-driven restrictions are implemented with clear justifications and safeguards.
#    * **Level 3 (High Risk - Emergency Situations):** AI deployment requires rigorous justification, demonstrable societal benefit, and failsafe mechanisms, with continuous human review.
#
# 3. **Dynamic Risk Assessment:**  AI systems aren't static. The effectiveness and potential risks change over time. A continuous risk assessment process is crucial, reviewed regularly and updated based on real-world outcomes, emerging research, and societal feedback.
#
# 4. **Redress Mechanisms:**  Individuals must have accessible and effective mechanisms to challenge AI decisions that affect them. This could include:
#     * **Independent Auditing Boards:**  Expert bodies to review AI systems and decision-making processes.
#     * **Right to Appeal:**  A clearly defined process for appealing AI decisions to a human authority.
#     * **Compensation Mechanisms:**  Addressing harms caused by AI errors or biases.
#
#
#
# **III. Ongoing Considerations & Caveats:**
#
# * **Context Specificity:** This framework isn't a one-size-fits-all solution. The specific application of these principles will depend on the domain (e.g., healthcare, criminal justice, urban planning).
# * **The Role of Human Judgment:** AI should augment, not replace, human judgment.  We need to foster a culture of critical thinking and ethical awareness among AI developers, deployers, and users.
# * **Continuous Dialogue:**  This framework shouldn't be static. It needs to be continuously debated, refined, and adapted as AI technology evolves and our understanding of its implications deepens.
#
# **To make this even more concrete, let’s consider a specific example:  AI-powered surveillance systems.** Applying this framework, the “value mapping” would identify tradeoffs between public safety and the right to privacy.  The “scale of intervention” would determine when facial recognition, predictive policing, or data collection are acceptable—likely only during genuine threats and with strict limitations on data retention and use.
#
#
#
# Do you want me to delve deeper into a specific aspect of this framework, such as:
#
# *   The challenges of defining and measuring ‘fairness’ in AI?
# *   How to build truly explainable AI systems?
# *   The role of regulation and governance in this process?
#
# # Response from competitor 2
#
# Creating an ethical framework for AI decision-making that balances utility with individual rights is a complex challenge, but it can be approached through a structured set of key principles. Here are some suggested principles, along with strategies for addressing potential conflicts between collective benefits and personal freedoms:
#
# ### Key Principles
#
# 1. **Human-Centric Design**: AI systems should prioritize human well-being and dignity. This involves designing algorithms that are transparent, understandable, and respect users’ rights. Human oversight should always be a part of AI decision-making processes.
#
# 2. **Transparency and Accountability**: AI systems must be transparent, enabling users and affected parties to understand how decisions are made. There should be clear accountability mechanisms in place so that individuals or organizations can be held responsible for AI decisions.
#
# 3. **Fairness and Non-Discrimination**: AI should be designed to minimize bias and promote fairness, ensuring that it does not systematically disadvantage any individual or group. Regular audits should be conducted to evaluate the equity of AI decisions.
#
# 4. **Data Privacy and Security**: Individual rights to privacy must be prioritized. Data should only be collected and processed with explicit consent, and users should have control over their data, including the ability to delete it.
#
# 5. **Autonomy and Consent**: Individuals should maintain agency over their choices, with AI systems facilitating rather than dictating decisions. Informed consent must be obtained, especially for impactful automated decisions.
#
# 6. **Collective Benefit with Individual Protection**: The framework should establish a balance between collective utility and individual rights. Actions that benefit society as a whole should not infringe upon personal rights unless justified by clear, ethical reasoning.
#
# 7. **Recourse and Remedy**: There should be accessible channels for individuals to contest AI decisions that impact them negatively. This includes mechanisms for review, appeals, and rectification.
#
# 8. **Continuous Evaluation and Adaptation**: The principles guiding AI should evolve alongside societal norms, technological advances, and feedback. Regular assessments and revisions of AI policies and practices are essential to keep pace with change.
#
# ### Addressing Conflicts between Collective Benefits and Personal Freedoms
#
# In situations where collective benefits conflict with individual rights, the framework may involve several strategies:
#
# 1. **Justification of Trade-offs**: Establish strict guidelines that carefully assess when collective benefits justify the infringement on personal freedoms. These guidelines should require that any trade-off must serve a significant public interest and should be the least restrictive approach available.
#
# 2. **Proportionality Principle**: Adopt a proportionality principle where the benefits of a collective action must outweigh the harm or restriction placed on individual rights. This would require a thorough analysis of potential outcomes before decisions are made.
#
# 3. **Stakeholder Participation**: Engage diverse stakeholders in the decision-making process, including representatives from affected communities, ethicists, and policymakers. This can help to find a balance that reflects the values and priorities of broader society while considering individual concerns.
#
# 4. **Deliberation and Democratic Processes**: Establish forums for public deliberation and democratic processes around significant AI use cases, allowing collective input and discussion on ethical dilemmas posed by AI.
#
# 5. **Impact Assessments**: Require impact assessments for AI implementations, considering both individual rights and societal impacts. These assessments should be mandatory before deployment and must include plans for mitigating negative effects on personal freedoms.
#
# 6. **Ethics Committee Oversight**: Create independent ethics committees to review controversial AI applications and adjudicate conflicts between collective benefits and individual rights. These committees can provide recommendations based on ethical principles, public interest, and individual rights.
#
# By adhering to these principles and implementing mechanisms to address conflicts, the ethical framework for AI decision-making can contribute to a balanced, fair, and just use of AI technology.
#
# # Response from competitor 3
#
# <think>
# Okay, the user is asking about creating an ethical framework for AI decision-making that balances utility with individual rights. This is a complex and important question. First, I need to understand what they really need. They might be someone in tech ethics, policy-making, or maybe a student researching AI ethics. Their main request is for key principles and conflict resolution strategies.
#
# Hmm, the user specifically wants to know how to handle conflicts between collective benefits and personal freedoms. That's a tough area because AI decisions can really impact people's lives. For example, a recommendation system that shows you more ads might be useful for businesses but invade privacy. Or algorithms in hiring that increase efficiency but discriminate against certain groups.
#
# I should start by recalling existing frameworks. There's the EU AI Act, IEEE guidelines, but they might not cover all aspects. The user wants something new, so I need to think beyond current models. Key principles should be clear, actionable, and address both utility and rights.
#
# First principle: Human oversight. AI shouldn't make decisions without human intervention. But how much oversight? Maybe a tiered system where high-impact decisions require humans. That way, utility isn't compromised but rights are protected.
#
# Second principle: Right to explanation. People should understand why AI made a decision affecting them. But in complex systems, this is hard. Need to think about technical feasibility—maybe through user-friendly interfaces without overcomplicating.
#
# Third principle: Proportionality. The AI's impact on rights should match the utility gained. If an algorithm uses someone's data without consent for a minor benefit, that's not proportional. But how to measure this? Maybe by impact assessments before deployment.
#
# Fourth principle: Data minimization. Collect only what's necessary. The user might be concerned about data privacy, so this is crucial. But AI often needs large datasets, so there's a tension here. Need to balance with utility.
#
# Fifth principle: Democratic accountability. Who's responsible when things go wrong? The user mentioned conflicts between collective benefits and personal freedoms, so accountability mechanisms are key. Like having independent bodies review AI systems.
#
# Wait, the user also asked about addressing conflicts. So I should outline strategies for when there's a clash. For instance, if an AI improves healthcare but requires sharing health data, how do we handle that? Maybe through strict consent protocols, anonymization, and opt-in for data sharing. But what if the collective benefit is huge, like pandemic response? Then maybe override personal rights temporarily with safeguards.
#
# Another angle: The user might be worried about real-world applications. Like facial recognition for public safety versus privacy. Current systems often bypass rights. So the framework should have clear thresholds—when can rights be overridden? Like only in emergencies with judicial oversight.
#
# Also, cultural context matters. In some regions, privacy rights are stronger than in others. The framework should be flexible but grounded in universal human rights. But the user didn't mention cultural aspects, so maybe keep it broad.
#
# I recall the principle of "least restrictive alternative." Instead of using AI that infringes on rights, find the minimal way to achieve the goal. For example, using AI for credit scoring but with manual reviews for high-risk applicants. That balances utility with rights.
#
# Conflict resolution mechanisms: If an AI decision harms someone, there should be a process for redress. Maybe an independent review board that can reverse decisions and ensure the rights are restored. Also, continuous monitoring to catch biases early.
#
# The user might have deeper concerns about bias and fairness. Like AI reinforcing societal inequalities. So the framework should include fairness metrics that are culturally sensitive. But fairness is subjective—how to define it? Maybe through multiple lenses: gender, race, socioeconomic status.
#
# Also, the term "utility" is tricky. Is it societal benefit, economic gain, or individual well-being? The framework should define utility clearly to avoid misuse. Like, if an AI saves lives but requires invasive monitoring, is that useful? Need to prioritize human well-being over pure efficiency.
#
# Potential pitfalls: Overcomplicating the framework might lead to impracticality. Need to be realistic. For instance, explaining AI decisions in real-time for complex systems could be impossible. So the framework should allow for simplified explanations where possible.
#
# Testing the framework with real cases. For example, in hiring tools: utility is faster hiring, but rights include preventing discrimination. The framework would require bias testing and human review for high-stakes roles. If a tool increases hiring speed but favors certain groups, it's rejected until fixed.
#
# The user might also be interested in implementation. How do organizations adopt this? Maybe through phased rollouts with pilot programs and feedback loops. Training stakeholders to understand the principles.
#
# I should structure the answer into core principles and then conflict resolution strategies. Make sure each principle addresses both utility and rights. Highlight how they resolve conflicts without being too abstract.
#
# Also, emphasize dynamic adaptation. AI ethics isn't static—frameworks need regular updates as tech evolves. Maybe include a clause for periodic reviews by independent bodies.
#
# One more thought: The right to withdraw. People should be able to opt out of AI decisions affecting them. Like, if an AI uses your data for advertising, you can delete your account. But in some contexts, like healthcare, withdrawing might not be feasible. So the framework should have exceptions with safeguards.
#
# Putting it all together: Start with a brief intro on why this matters, then list 4-5 key principles with clear explanations. For conflicts, provide concrete strategies like impact assessments, proportional overrides with checks, and redress mechanisms.
#
# Check if the user is looking for something actionable for policymakers versus developers. Since the question says "create a new framework," probably a comprehensive one but practical. Avoid academic jargon to keep it accessible.
#
# Also, consider global applicability. The framework should work in different legal systems. Maybe reference existing international rights frameworks like Universal Declaration of Human Rights.
#
# Alright, I think I have a structure. Principles: Human Oversight, Proportionality, Explainability, Data Minimization, Democratic Accountability. Then conflict resolution through impact assessments, proportional overrides, and redress processes. Make sure to tie each to balancing utility and rights.
# </think>
#
# Creating a new ethical framework for AI decision-making that **rigorously balances utility with individual rights** requires addressing both *practical realities* (e.g., real-world AI applications) and *deep philosophical tensions* (e.g., collective progress vs. personal autonomy). After extensive analysis of existing frameworks (like the EU AI Act, IEEE Ethics Taxonomy, and NIST guidelines), I’d design a framework focused on **practical, enforceable principles** that avoid theoretical overreach. Below is my proposed framework, prioritizing *actionable clarity* and *conflict resolution mechanisms*—key gaps in current approaches.
#
# ---
#
# ### ✅ Core Principles of the Framework: The "Right Utility-Right" Framework
# *(Designed to be implemented at the design, deployment, and operational stages of AI systems)*
#
# 1. **Human Oversight as the Default (Not a Luxury)**
#    - *Why?* AI decisions that affect lives (e.g., loan approvals, healthcare, criminal sentencing) must have *human intervention* as the first line of accountability.
#    - *How it balances utility & rights*:
#      - **Utility**: Prevents "over-optimization" where AI maximizes efficiency at the cost of human judgment (e.g., an algorithm that cuts hiring costs by 30% but hires fewer qualified candidates).
#      - **Rights**: Ensures individuals have a path to contest decisions (e.g., a person denied credit can appeal to a human reviewer).
#    - *Implementation*: Tiered oversight: High-stakes decisions (e.g., life/health) require *immediate* human review; mid-stakes (e.g., marketing targeting) allow automated checks with *real-time appeal channels*.
#
# 2. **Proportional Impact Principle**
#    - *Why?* Most AI frameworks focus on *outcomes* but ignore *how much* rights are infringed relative to utility gained.
#    - *How it balances utility & rights*:
#      - **Utility**: Quantifies *net benefit* (e.g., "This AI reduces hospital wait times by 20% but requires 500 extra health data points").
#      - **Rights**: Requires that the *infringed right* (e.g., privacy, autonomy) must be *proportionally less severe* than the utility gain.
#      - *Example*: A pandemic AI that tracks mobility (infringing privacy) is justified *only if* it saves >10 lives per 100 people tracked—**not** because it "reduces spread" (a vague utility).
#    - *Implementation*: Pre-deployment "impact scoring" using standardized metrics (e.g., [EU’s risk-based scoring](https://ec.europa.eu/info/law/privacy-act/ai-regulation_en) but simplified).
#
# 3. **Minimal Data & Contextual Explanation**
#    - *Why?* Data hoarding is a major rights violation; opaque AI undermines accountability.
#    - *How it balances utility & rights*:
#      - **Utility**: AI uses *only data necessary* for the task (e.g., a hiring tool doesn’t need full employment history).
#      - **Rights**: *Explains* decisions in simple terms *without* technical jargon (e.g., "We denied your loan because 85% of applicants with your background had late payments").
#    - *Implementation*: Data minimization rules + "explainability-by-design" (e.g., AI systems must output 3–5 key reasons for decisions via a user-friendly interface).
#
# 4. **Right to Contest & Redress**
#    - *Why?* Current frameworks often treat "appeals" as after-the-fact fixes, ignoring *prevention*.
#    - *How it balances utility & rights*:
#      - **Utility**: Establishes *rapid* redress (e.g., <72 hours for corrections) to avoid system failure.
#      - **Rights**: Guarantees individuals can *stop* AI decisions affecting them (e.g., "If your privacy was violated in a health scan, you can halt future scans at no cost").
#    - *Implementation*: Mandatory redress channels co-designed with users (e.g., automated dispute resolution with a human reviewer).
#
# 5. **Democratic Accountability**
#    - *Why?* Traditional "technical" accountability (e.g., "the developers are responsible") ignores *who* benefits.
#    - *How it balances utility & rights*:
#      - **Utility**: AI systems must align with *community values* (e.g., in a town with low income, an AI for job matching prioritizes local opportunities over global scalability).
#      - **Rights**: Prevents "utility capture" by elites (e.g., an AI that boosts profits for corporations but harms marginalized groups).
#    - *Implementation*: Independent oversight bodies (e.g., local "AI ethics boards") with power to *halt* deployments violating rights.
#
# ---
#
# ### 🔥 Key Conflict Resolution Strategy: The "Proportional Override Test"
# This is where most frameworks fail. Instead of *vaguely* saying "rights trump utility," we create a **quantifiable, time-bound test** to resolve clashes between collective benefits and personal freedoms.
#
# | **Scenario**                                | **Proportional Override Test**                                                                                                                              | **Why it Works**                                                                                               |
# |---------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|
# | *AI denies credit due to past debt*         | 1. Does the AI gain **net utility** (e.g., 20% fewer defaults) <br> 2. Is the *infringed right* (privacy) **proportional**? (e.g., 1 credit check = minor privacy risk vs. 20% utility gain) <br> 3. Can the user **contest** in <72 hours? | Avoids "black box" decisions; forces trade-offs to be *measurable* and *time-bound*—not theoretical.               |
# | *Government uses AI for public health tracking* | 1. Does the AI save **>5 lives per 1,000 tracked**? <br> 2. Is the *infringed right* (privacy) **minimal** (e.g., anonymized data only)? <br> 3. Is a **community review** (not just officials) conducted? | Ties utility to *human lives* (not abstract "safety"), prevents mass surveillance, and centers *community* input. |
# | *AI filters job applications by ethnicity*   | 1. Does the utility gain (e.g., 10% faster hiring) **exceed** the harm (e.g., 1% discrimination)? <br> 2. Is there *human review* for high-risk decisions? <br> 3. Can affected groups **opt out**? | Focuses on *quantifiable harm* (not just "bias"), not just "fairness" metrics.                                |
#
# **Why this test resolves conflicts without compromising either side**:
# - It **quantifies** utility and rights (no more "it’s for the greater good" hand-waving).
# - It **enforces deadlines** (e.g., 72-hour redress) to prevent *long-term* rights erosion.
# - It **requires community input** (not just tech teams or governments), ensuring utility aligns with *real* human values.
#
# ---
#
# ### 🌐 Why This Framework Works in Practice (Key Innovations)
# 1. **No "trade-off" language**: Instead of "utility vs. rights," it frames *proportional* trade-offs as **manageable risks** (e.g., "This AI costs 1% of your privacy for 20% utility gain").
# 2. **Anti-automation bias**: Explicitly requires human review *first*—not a "check" after the fact. This prevents systems from becoming self-sustaining "black boxes."
# 3. **Real-world testing**: Built to work with *existing* tech (e.g., explainability tools like SHAP, data minimization via GDPR-compliant APIs) without needing new infrastructure.
# 4. **Cultural adaptability**: Principles scale from local (e.g., a village-level farming AI) to global (e.g., climate models) by anchoring utility in *local metrics* (e.g., "fewer crop losses" vs. "carbon reduction").
#
# > 💡 **Example in Action**: In a low-income community using AI for food distribution:
# > - *Utility*: AI predicts famine risks and cuts supply chains by 25%.
# > - *Rights*: Requires *opt-in* for location data, *minimal* data usage (only 3 days of weather), and a human reviewer for critical cases.
# > - **Proportional Override Test**: If 500 people are denied aid due to data privacy (infringed right), but 100 people were saved (utility), the AI is *paused* for 72 hours—*not* automatically "approved" because the harm outweighs the benefit.
#
# ---
#
# ### 🔚 Final Thought: Why This Avoids Common Pitfalls
# Most AI ethics frameworks fail because they **overlook implementation** (e.g., "explainability" is impossible in complex systems) or **prioritize theory over action** (e.g., "rights" without concrete redress channels). *My framework focuses on the "what" (quantifiable trade-offs) and "how" (time-bound, human-led processes)*—not just ideals. It’s designed so that AI systems *must* pass the **Proportional Override Test** to operate, turning abstract ethics into **operational reality**.
#
# This isn’t about *perfect* balance—it’s about **intelligent trade-offs with accountability**. In a world where AI decisions increasingly affect human lives, we can’t have frameworks that work on paper but fail in practice. The Right Utility-Right Framework gives stakeholders (users, developers, regulators) the tools to make *real* choices—not just moral ones.
#
# *Would you like me to draft a practical implementation guide for governments, or explore how this handles specific high-stakes scenarios (e.g., criminal justice, healthcare)?*

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# If you were tasked with creating a new ethical framework for AI decision-making that balances utility with individual rights, what key principles would you include, and how would you address potential conflicts between collective benefits and personal freedoms?
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Okay, this is a hugely important and complex challenge. Designing an ethical framework for AI decision-making that truly balances utility with individual rights requires a layered approach, constantly considering context and potential unintended consequences. Here's a framework I’d propose, built around several key principles and a mechanism for managing conflicts:
#
# **I. Core Principles:**
#
# 1. **Human Dignity as the Foundation:**  This isn't just about avoiding harm; it’s about recognizing the inherent worth and autonomy of every human being. AI decisions should always operate with the assumption that human well-being is paramount.
#
# 2. **Transparency & Explainability (Beyond Black Boxes):**
#    * **Algorithmic Accountability:** We need robust mechanisms to trace decisions back to the data, the model, and the reasoning process. This goes beyond just “explainable AI” – it demands demonstrable accountability.
#    * **Human-in-the-Loop Oversight:** Humans must retain the capacity to override AI decisions, particularly in high-stakes situations.
#    * **Data Provenance & Bias Auditing:**  Constant monitoring of the data used to train AI is critical.  Regular, independent audits for bias are non-negotiable.
#
# 3. **Proportionality & Necessity:** Any intervention by AI (e.g., restricting movement, limiting access to services) must be proportionate to the identified problem and demonstrably necessary. There should be a clear cost-benefit analysis, not just a mathematical one, considering social and psychological factors.
#
# 4. **Fairness & Equity (Beyond Simple Equality):**  Fairness isn't just about treating everyone the same. It requires addressing systemic biases within data and algorithms, and actively striving for equitable outcomes considering diverse societal contexts and historical injustices. This necessitates defining 'fairness' itself – different definitions (e.g., equality of opportunity vs. equality of outcome) might be appropriate in different domains.
#
# 5. **Respect for Autonomy & Informed Consent:** Whenever possible, individuals should have agency in decisions that affect them. This includes the right to understand how AI is being used, the opportunity to opt-out (where feasible), and the right to correct inaccuracies in data about themselves.
#
#
#
# **II. Addressing Conflicts: A Layered Conflict Resolution Framework**
#
# Because conflicts between collective benefit and individual freedoms are inevitable, we need a system for resolving them:
#
# 1. **Value Mapping & Stakeholder Engagement:** Before deploying any AI system, a thorough "value mapping" exercise is required. This identifies the primary values at stake (e.g., public safety vs. privacy, economic growth vs. social justice) and involves extensive consultation with diverse stakeholder groups – including marginalized communities – to understand their concerns.
#
# 2. **Scales of Intervention:**  We need to establish clear, publicly accessible "scales of intervention" that outline the conditions under which AI can be deployed to restrict individual freedoms. These wouldn't be rigid rules, but rather a framework for assessing the severity of the situation.  Examples:
#    * **Level 1 (Low Risk):** AI assists with recommendations; individuals retain full control.
#    * **Level 2 (Moderate Risk):** AI provides guidance, but human oversight is mandatory; data-driven restrictions are implemented with clear justifications and safeguards.
#    * **Level 3 (High Risk - Emergency Situations):** AI deployment requires rigorous justification, demonstrable societal benefit, and failsafe mechanisms, with continuous human review.
#
# 3. **Dynamic Risk Assessment:**  AI systems aren't static. The effectiveness and potential risks change over time. A continuous risk assessment process is crucial, reviewed regularly and updated based on real-world outcomes, emerging research, and societal feedback.
#
# 4. **Redress Mechanisms:**  Individuals must have accessible and effective mechanisms to challenge AI decisions that affect them. This could include:
#     * **Independent Auditing Boards:**  Expert bodies to review AI systems and decision-making processes.
#     * **Right to Appeal:**  A clearly defined process for appealing AI decisions to a human authority.
#     * **Compensation Mechanisms:**  Addressing harms caused by AI errors or biases.
#
#
#
# **III. Ongoing Considerations & Caveats:**
#
# * **Context Specificity:** This framework isn't a one-size-fits-all solution. The specific application of these principles will depend on the domain (e.g., healthcare, criminal justice, urban planning).
# * **The Role of Human Judgment:** AI should augment, not replace, human judgment.  We need to foster a culture of critical thinking and ethical awareness among AI developers, deployers, and users.
# * **Continuous Dialogue:**  This framework shouldn't be static. It needs to be continuously debated, refined, and adapted as AI technology evolves and our understanding of its implications deepens.
#
# **To make this even more concrete, let’s consider a specific example:  AI-powered surveillance systems.** Applying this framework, the “value mapping” would identify tradeoffs between public safety and the right to privacy.  The “scale of intervention” would determine when facial recognition, predictive policing, or data collection are acceptable—likely only during genuine threats and with strict limitations on data retention and use.
#
#
#
# Do you want me to delve deeper into a specific aspect of this framework, such as:
#
# *   The challenges of defining and measuring ‘fairness’ in AI?
# *   How to build truly explainable AI systems?
# *   The role of regulation and governance in this process?
#
# # Response from competitor 2
#
# Creating an ethical framework for AI decision-making that balances utility with individual rights is a complex challenge, but it can be approached through a structured set of key principles. Here are some suggested principles, along with strategies for addressing potential conflicts between collective benefits and personal freedoms:
#
# ### Key Principles
#
# 1. **Human-Centric Design**: AI systems should prioritize human well-being and dignity. This involves designing algorithms that are transparent, understandable, and respect users’ rights. Human oversight should always be a part of AI decision-making processes.
#
# 2. **Transparency and Accountability**: AI systems must be transparent, enabling users and affected parties to understand how decisions are made. There should be clear accountability mechanisms in place so that individuals or organizations can be held responsible for AI decisions.
#
# 3. **Fairness and Non-Discrimination**: AI should be designed to minimize bias and promote fairness, ensuring that it does not systematically disadvantage any individual or group. Regular audits should be conducted to evaluate the equity of AI decisions.
#
# 4. **Data Privacy and Security**: Individual rights to privacy must be prioritized. Data should only be collected and processed with explicit consent, and users should have control over their data, including the ability to delete it.
#
# 5. **Autonomy and Consent**: Individuals should maintain agency over their choices, with AI systems facilitating rather than dictating decisions. Informed consent must be obtained, especially for impactful automated decisions.
#
# 6. **Collective Benefit with Individual Protection**: The framework should establish a balance between collective utility and individual rights. Actions that benefit society as a whole should not infringe upon personal rights unless justified by clear, ethical reasoning.
#
# 7. **Recourse and Remedy**: There should be accessible channels for individuals to contest AI decisions that impact them negatively. This includes mechanisms for review, appeals, and rectification.
#
# 8. **Continuous Evaluation and Adaptation**: The principles guiding AI should evolve alongside societal norms, technological advances, and feedback. Regular assessments and revisions of AI policies and practices are essential to keep pace with change.
#
# ### Addressing Conflicts between Collective Benefits and Personal Freedoms
#
# In situations where collective benefits conflict with individual rights, the framework may involve several strategies:
#
# 1. **Justification of Trade-offs**: Establish strict guidelines that carefully assess when collective benefits justify the infringement on personal freedoms. These guidelines should require that any trade-off must serve a significant public interest and should be the least restrictive approach available.
#
# 2. **Proportionality Principle**: Adopt a proportionality principle where the benefits of a collective action must outweigh the harm or restriction placed on individual rights. This would require a thorough analysis of potential outcomes before decisions are made.
#
# 3. **Stakeholder Participation**: Engage diverse stakeholders in the decision-making process, including representatives from affected communities, ethicists, and policymakers. This can help to find a balance that reflects the values and priorities of broader society while considering individual concerns.
#
# 4. **Deliberation and Democratic Processes**: Establish forums for public deliberation and democratic processes around significant AI use cases, allowing collective input and discussion on ethical dilemmas posed by AI.
#
# 5. **Impact Assessments**: Require impact assessments for AI implementations, considering both individual rights and societal impacts. These assessments should be mandatory before deployment and must include plans for mitigating negative effects on personal freedoms.
#
# 6. **Ethics Committee Oversight**: Create independent ethics committees to review controversial AI applications and adjudicate conflicts between collective benefits and individual rights. These committees can provide recommendations based on ethical principles, public interest, and individual rights.
#
# By adhering to these principles and implementing mechanisms to address conflicts, the ethical framework for AI decision-making can contribute to a balanced, fair, and just use of AI technology.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": [1, 2, 3]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemma3:4b
# Rank 2: gpt-4o-mini
# Rank 3: qwen3:4b

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
